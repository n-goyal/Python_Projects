# %% [markdown]
# ### Downloading Kaggle Client from google drive in place of uploading everytime!

# %%
#Adding Kaggle API token from google drive
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
path = '/content/drive/My Drive/Colab Notebooks'
os.chdir(path)

#make sure kaggle.json is still present in the drive - folder
# !ls -lha kaggle.json
# Out:
# -rw------- 1 root root 68 Feb 27 11:21 kaggle.json

# %%
#Download Kaggle Client
# !pip install -q kaggle

#kaggle client expects kaggle.json in it
# !mkdir -p ~/.kaggle

#copying kaggle.json from drive to the path
# !cp '/content/drive/My Drive/Colab Notebooks/kaggle.json' ~/.kaggle

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# List available datasets.
# !kaggle datasets list
# Out:
# ref                                                          title                                                size  lastUpdated          downloadCount
# -----------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# ronitf/heart-disease-uci                                     Heart Disease UCI                                     3KB  2018-06-25 11:33:56          10293
# russellyates88/suicide-rates-overview-1985-to-2016           Suicide Rates Overview 1985 to 2016                 396KB  2018-12-01 19:18:25           7278
# lava18/google-play-store-apps                                Google Play Store Apps                                2MB  2019-02-03 13:55:47          38365
# karangadiya/fifa19                                           FIFA 19 complete player dataset                       2MB  2018-12-21 03:52:59          10422
# ...

# %% [markdown]
# ### Download dataset

# %%
# Downloading the partial discharge dataset from kaggle
# !kaggle competitions download -c vsb-power-line-fault-detection
# Out:
# metadata_test.csv: Skipping, found more recently modified local copy (use --force to force download)
# metadata_train.csv: Skipping, found more recently modified local copy (use --force to force download)
# sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# ...
# 100% 6.96G/6.97G [01:30<00:00, 111MB/s]
# 100% 6.97G/6.97G [01:30<00:00, 82.5MB/s]
# ...
# 100% 3.02G/3.02G [00:54<00:00, 44.6MB/s]
# 100% 3.02G/3.02G [00:54<00:00, 59.2MB/s]

# %%
# I made a mistake i forgot to change path back to colab
# dataset hence has been downloaded to the specified path

# %% [markdown]
# ### Reading Data files

# %%
# import necessary packages
  
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn
# !pip install pyarrow
import pyarrow.parquet as pq
import time
from tqdm import tqdm
# Out:
# ...
#     100% |████████████████████████████████| 12.4MB 3.2MB/s
# ...

# %%
#unzipping the train and test data
import glob
import zipfile
from pathlib import Path
zip_files = glob.glob(path+'/*.zip')
zip_files
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-96a5abd47004> in <module>()
#       2 import zipfile
#       3 from pathlib import Path
# ----> 4 zip_files = glob.glob(path+'/*.zip')
#       5 zip_files
#
# NameError: name 'path' is not defined

# %%
for file in zip_files:
  zip_ref = zipfile.ZipFile(file, 'r')
  file_name = Path(file).stem
  zip_ref.extractall('/content/Unzipped/'+file_name)
  zip_ref.close()

# %%
#reading signal - files as pandas
# %time
signals = pd.read_parquet('/content/Unzipped/train.parquet/train.parquet', engine='auto')
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.2 µs
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-0fc6d6f8f4ab> in <module>()
#       1 get_ipython().magic('time')
# ----> 2 signals = pd.read_parquet('/content/Unzipped/train.parquet/train.parquet', engine='auto')
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, **kwargs)
#     255
#     256     impl = get_engine(engine)
# --> 257     return impl.read(path, columns=columns, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parquet.py in read(self, path, columns, **kwargs)
#     128         kwargs['use_pandas_metadata'] = True
#     129         return self.api.parquet.read_table(path, columns=columns,
# --> 130                                            **kwargs).to_pandas()
#     131
# ...

# %%
#preparing data
signals.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e80ec3c00c0c> in <module>()
# ----> 1 signals.head()
#
# NameError: name 'signals' is not defined

# %%
#building model - Autoencoders

# %%
#Feature extraction - training autoencoders

# %%
#preparing a classification model

# %%
#fine tuning the model - assembling the encoded feature layer with traditional classification layer

# %%
# !ps ax | grep python
# Out:
#      46 ?        Sl     0:07 /usr/bin/python2 /usr/local/bin/jupyter-notebook --ip="172.28.0.2" --port=9000 --FileContentsManager.root_dir="/" --MappingKernelManager.root_dir="/content"
#     691 ?        Ssl    0:02 /usr/bin/python3 -m ipykernel_launcher -f /root/.local/share/jupyter/runtime/kernel-e30141ee-d132-435b-81bc-a7fbd809fe6b.json
#     710 ?        S      0:00 /usr/bin/python3 -Wignore:::pip._internal.cli.base_command -c from multiprocessing.semaphore_tracker import main;main(80)
#     770 ?        Ssl    0:02 /usr/bin/python3 -m ipykernel_launcher -f /root/.local/share/jupyter/runtime/kernel-1ab9f286-ba8d-4798-b97c-b27737bce2ad.json
#     786 ?        S      0:00 /usr/bin/python3 -Wignore:::pip._internal.cli.base_command -c from multiprocessing.semaphore_tracker import main;main(79)
#     823 ?        S      0:00 /bin/bash -c ps ax | grep python
#     825 ?        D      0:00 grep python

# %%
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# Successfully built gputil
# ...
# Gen RAM Free: 12.9 GB  | Proc size: 142.2 MB
# GPU RAM Free: 11441MB | Used: 0MB | Util   0% | Total 11441MB

# %%
 # !kill -9 -1
